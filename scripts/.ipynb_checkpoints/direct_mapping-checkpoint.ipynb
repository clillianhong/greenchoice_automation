# %%
import pandas as pd
import numpy as np
import io
import os
from sqlalchemy import *
import re

# %%
metadata = MetaData()
engine= create_engine('mysql+pymysql://gc:compare123@gcapp.c4xzfsrbmzt9.us-east-1.rds.amazonaws.com:3306/app_backend_db')
connection = engine.connect()
table = Table("ProductTableMerged", metadata, autoload=True, autoload_with=engine)
s = select([table.columns.productCode, table.columns.productName, table.columns.productCategory, 
            table.columns.productType, table.columns.ingredientList, table.columns.productNameSearch])

oldtable = pd.read_sql(s, connection)
# oldtable = oldtable.sample(n=1000)

new_cat = []
new_typ = [] 

def assign(x):
    c = x['productCategory'].lower()
    t = x['productType'].lower()
    
    nc = ""
    nt = ""
    
    if(t=="chocolate, cocoa & syrup"):
        nc = "snacks, chips, salsas & dips"
        nt = "candy & chocolate"
    elif(c =="beverages"):
        if(t == "cocktail & drink mixes"):
            nt = "cocktail & drink mixes"
            nc = "beverages"
        if(t == "coffee & tea"):
            nt = "coffee, tea & kombucha"
            nc = "beverages"
        if(t == "energy & sports drinks"):
            nt = "sports, energy & nutritional drinks"
            nc = "beverages"
        if(t == "juice"):
            nt = "juice"
            nc = "beverages"
        if(t == "soda"):
            nt = "soft drinks"
            nc = "beverages"
        if(t == "water & seltzer"):
            nt = "water, seltzer & sparkling water"
            nc = "beverages"
    elif(c == "bread and bakery"):
        if(t == "bread"): 
            nt = "breads"
            nc = "bread & bakery"
        if(t == "pastries & dessert"):
            nt = "pastries & desserts"
            nc = "bread & bakery"
        if(t == "pita, tortilla, wraps & flatbread") :
            nt = "pastries & desserts"
            nc = "bread & bakery"
    elif(c == "dairy and eggs"):
        if(t == "cheese"):
            nt = "cheese"
            nc = "dairy & eggs"
        if(t == "egg & egg substitutes"):
            nt = "egg & egg substitutes"
            nc = "dairy & eggs"
        if(t == "milk"):
            nt = "milks"
            nc = "dairy & eggs"
        if(t == "soy & milk alternatives"):
            nt = "milks"
            nc = "dairy & eggs"
        if(t == "yogurt"):
            nt = "yogurt"
            nc = "dairy & eggs"
    elif(c == "deli"):
        if(t == "cheese"):
            nc = "dairy & eggs"
            nt = "cheese"
        if(t == "meat & cold cuts"):
            nc = "meat"
            nt = "deli meat"
    elif(c == "frozen"):
        if(t == "breakfast"):
            nt = "frozen breakfast"
            nc = "frozen"
        if(t == "frozen bread & dough"):
            nt = "frozen doughs"
            nc = "frozen"
        if(t == "frozen desserts"):
            nt = "ice cream & frozen desserts"
            nc = "frozen"
        if(t == "frozen fruits & vegetables"):
            nt = "frozen fruits & vegetables"
            nc = "frozen"
        if(t == "frozen meals & appetizers"):
            nt = "frozen entrees & appetizers"
            nc = "frozen"
        if(t == "frozen meat & seafood"):
            nt = "frozen entrees & appetizers"
            nc = "frozen"
        if(t == "frozen meat alternatives"):
            nt = "frozen entrees & appetizers"
            nc = "frozen"
    elif(c == "meat"):
        if(t == "beef"):
            nt = "beef"
            nc = "meat"
        if(t == "chicken"):
            nt = "poultry"
            nc = "meat"
        if(t == "frozen meat alternatives"):
            nt = "meat alternatives"
            nc = "meat"
        if(t == "lamb"):
            nt = "veal, game & specialty"
            nc = "meat"
        if(t == "meat alternatives"):
            nt = "meat alternatives"
            nc = "meat"
        if(t == "pork"):
            nt = "pork"
            nc = "meat"
        if(t == "poultry"):
            nt = "poultry"
            nc = "meat"
        if(t == "veal, game & specialty"):
            nt = "veal, game & specialty"
            nc = "meat"
    elif(c == "pantry"):
        if(t == "baking essentials"):
            nt = "baking"
            nc = "pantry"
        if(t == "breakfast"):
            nt = "breakfast"
            nc = "pantry"
        if(t == "canned goods"):
            nt = "canned & preserved goods"
            nc = "pantry"
        if(t == "jam, jelly & spreads"):
            nt = "jams, jellies, & nut butters"
            nc = "pantry"
        if(t == "oil & vinegar"):
            nt = "seasoning, condiments & dressings"
            nc = "pantry"
        if(t == "rice, dry pasta, beans & grains"):
            nt = "rice, dry pasta, beans & grain"
            nc = "pantry"
        if(t == "seasoning, sauce & condiments"):
            nt = "seasoning, condiments & dressings"
            nc = "pantry"
        if(t == "sugar & sweeteners"):
            nt = "baking"
            nc = "pantry"
    elif(c == "prepared foods"):
        if(t == "appetizers & sides"):
            nt = "prepared soups & salads"
            nc = "prepared foods"
        if(t == "entrees"):
            nt = "prepared meals"
            nc = "prepared foods"
    elif(c == "produce"):
        if(t == "fruits"):
            nt = "fresh fruit"
            nc == "produce"
        if(t == "precut & ready to eat"):
            nt = "pre-cut & ready to eat"
            nc == "produce"
        if(t == "vegetables"):
            nt = "fresh vegetables"
            nc == "produce"
    elif(c == "seafood"):
        if(t == "fish"):
            nt = "fish"
            nc = "seafood"
        if(t == "shellfish"):
            nt = "shellfish"
            nc = "seafood"
    elif(nc == "" and nt == ""):
        nc = "RETAGGED"
        nt = "RETAGGED"
        
    new_cat.append(nc)
    new_typ.append(nt)
    
oldtable.apply(lambda x: assign(x), axis=1)
    
oldtable['oldCategory'] = oldtable['productCategory']
oldtable['oldType'] = oldtable['productType']
oldtable['productCategory'] = new_cat
oldtable['productType'] = new_typ

oldtable.to_sql("training_table_lillian_hong", con=engine, if_exists='replace')

# %%
print(oldtable)
# Out:
#                     productCode  \
# 56945         SKU_759033Wegmans
# 19528  5c1cbe6b65b1774c6108cd93
# 19625  5c1cbeae65b1774c610a15ac
# 7152            22309181Walmart
# 29185           892551Hannaford
# 17978  5c1cb95265b1774c61ee3533
# 42920             GC35188frozen
# 16064  5c1cb35265b1774c61cef544
# 20668  5c5d6caef1564f0c2f5fbe54
# 53763         SKU_613987Wegmans
# 29400           901392Hannaford
# 23984          658320795Walmart
# 23288  5cede572206706384592c543
# 6431           204352245Walmart
# 31511           938178Hannaford
# 49583          SKU_33869Wegmans
# 13961           55357971Walmart
# 42051             GC23796pantry
# 1227            10315010Walmart
# 35351          A-13291470Target
# 24129          696176170Walmart
# 16055  5c1cb34765b1774c61cec180
# 28293          835593418Walmart
# 51990         SKU_486423Wegmans
# 20558  5c4a4763a5ffb27db41ff923
# 32868           960022Hannaford
# 38365          A-51522491Target
# 33948         Hannaford Sausage Stir Fry With Vegetables
# 15673   thinkThin Chocolate Cake Protein Cakes , 1.48 oz
# 4598                Moxie Original Soda, 12 Fl Oz, Count       beverages
# 23936                Great Value Mozzarella Sticks, 8 oz          frozen
# 1577    Yoplait Whips Yogurt Gluten Free Strawberry 4 oz    dairy & eggs
# 32982                          Penne Meatball Meal Small  prepared foods
# 54872  Birds Eye Steamfresh Veggie Made Cauliflower, ...          frozen
# 13463  Tombstone Roadhouse Piled High Pepperoni Froze...          frozen
# 15578   The Blooming Oven Cauliflower Pizza Crust , 5 oz          frozen
# 50120               Wegmans Sprouted Grain Bread 12 Loaf  bread & bakery
# 7458   Vitaminwater Zero Rise Orange Water Beverage, ...       beverages
# 32471                           Pastene Hot Garden Salad
# 48421                             Ahi Tuna Sashimi Style  prepared foods
# 19768  365 Everyday Value Vanilla Coconut Milk , 32 F...    dairy & eggs
# 54840              SmartMade White Wine Chicken Couscous  prepared foods
# 23245  JENIS SPLENDID ICE CREAMS Supermoon Ice Cream ...          frozen
# 21393              Bearitos Buffalo Corn Chips , 8.25 oz
# 53651               Turkey Hill Strawberry Kiwi Lemonade       beverages
# 47819  Wegmans Ready to Cook Kansas City BBQ Ribeye S...
# 30271           Nature's Promise Organic Kombucha Ginger       beverages
# 31939                        Meal Mart Beef Ribeye Steak        RETAGGED
# 22086  365 Everyday Value Key West Pink Shrimp 6070 C...
# 30864                Oscar Mayer Lunchables Unos S'mores            meat
# 3895                                Honeydew Melon, Each
# 20267                           PRODUCE Soy Bean Sprouts
# 55495      Honest Tea Peach Ginger Tea, Unsweet, Organic       beverages
# 38972  Pop Tarts Brown Sugar Cinnamon 32ct564oz Kello...          pantry
# 4783   Eckrich Deli Pickle Pimento Loaf, Fully Cooked...            meat
# 42204  Chef Boyardee Mini Spaghetti and Meatballs, 14...
# 10541  Birds Eye Voila Balsamic Glazed Chicken 42 oz Bag          frozen
#
#                                productType  \
# 56945                               cheese
# 19528
# 19625
# 7152
# 29185                  pastries & desserts
# 17978             canned & preserved goods
# 42920          frozen entrees & appetizers
# 16064                                milks
# 20668
# 53763
# 29400
# 23984
# 23288
# 6431           frozen entrees & appetizers
# 31511                               breads
# 49583              prepared soups & salads
# 13961
# 42051
# 1227              canned & preserved goods
# 35351          ice cream & frozen desserts
# 24129
# 16055    seasoning, condiments & dressings
# 28293
# 51990
# 20558                          fresh fruit
# 32868
# 38365
# 19198               coffee, tea & kombucha
# 29680                            breakfast
# 19596
# ...                                    ...
# 33948
# 15673
# 4598                           soft drinks
# 23936          frozen entrees & appetizers
# 1577                                yogurt
# 32982                       prepared meals
# 54872           frozen fruits & vegetables
# 13463          frozen entrees & appetizers
# 15578          frozen entrees & appetizers
# 50120                               breads
# 7458   sports, energy & nutritional drinks
# 32471
# 48421                       prepared meals
# 19768                                milks
# 54840                       prepared meals
# 23245          ice cream & frozen desserts
# 21393
# 53651                                juice
# 47819
# 30271               coffee, tea & kombucha
# 31939                             RETAGGED
# 15578    The Blooming Oven Cauliflower Pizza Crust  5 oz            frozen
# 50120               Wegmans Sprouted Grain Bread 12 Loaf  bread and bakery
# 7458   Vitaminwater Zero Rise Orange Water Beverage 1...         beverages
# 32471                           Pastene Hot Garden Salad            pantry
# 48421                             Ahi Tuna Sashimi Style    prepared foods
# 19768  365 Everyday Value Vanilla Coconut Milk  32 FL OZ    dairy and eggs
# 54840              SmartMade White Wine Chicken Couscous    prepared foods
# 23245  JENIS SPLENDID ICE CREAMS Supermoon Ice Cream ...            frozen
# 21393                Bearitos Buffalo Corn Chips  825 oz            pantry
# 53651               Turkey Hill Strawberry Kiwi Lemonade         beverages
# 47819  Wegmans Ready to Cook Kansas City BBQ Ribeye S...              meat
# 30271            Natures Promise Organic Kombucha Ginger         beverages
# 31939                        Meal Mart Beef Ribeye Steak     miscellaneous
# 22086  365 Everyday Value Key West Pink Shrimp 6070 C...           seafood
# 30864                 Oscar Mayer Lunchables Unos Smores              deli
# 3895                                 Honeydew Melon Each           produce
# 20267                           PRODUCE Soy Bean Sprouts           produce
# 55495        Honest Tea Peach Ginger Tea Unsweet Organic         beverages
# 38972  Pop Tarts Brown Sugar Cinnamon 32ct564oz Kelloggs            pantry
# 4783   Eckrich Deli Pickle Pimento Loaf Fully Cooked ...              deli
# 42204  Chef Boyardee Mini Spaghetti and Meatballs 145 oz            pantry
# 10541  Birds Eye Voila Balsamic Glazed Chicken 42 oz Bag            frozen
#
#                              oldType
# 56945                         cheese
# 19528         precut & ready to cook
# 19625                 candy & snacks
# 7152                  candy & snacks
# 29185             pastries & dessert
# 17978                   canned goods
# 42920       frozen meat alternatives
# 16064        soy & milk alternatives
# 20668                      specialty
# 53763            international foods
# 29400            international foods
# 23984                 candy & snacks
# 23288                 candy & snacks
# 6431       frozen meals & appetizers
# 31511                          bread
# 49583             appetizers & sides
# 13961                 candy & snacks
# 42051                 candy & snacks
# 1227                    canned goods
# 35351                frozen desserts
# 24129                 candy & snacks
# 16055  seasoning, sauce & condiments
# 28293                 candy & snacks
# 51990            international foods
# 20558                         fruits
# 32868         precut & ready to cook
# 38365     desserts, cream & creamers
# 19198                   coffee & tea
# 29680                      breakfast
# 19596                 candy & snacks
# ...                              ...
# 33948         precut & ready to cook
# 15673                 candy & snacks
# 4598                            soda
# 23936      frozen meals & appetizers
# 1577                          yogurt
# 32982                        entrees
# 54872     frozen fruits & vegetables
# 13463      frozen meals & appetizers
# 15578      frozen meals & appetizers
# 50120                          bread
# 7458          energy & sports drinks
# 32471            international foods
# 48421                        entrees
# 19768        soy & milk alternatives
# 54840                        entrees
# 23245                frozen desserts
# 21393                 candy & snacks
# 53651                          juice
# 47819         precut & ready to cook
# 30271                   coffee & tea
# 31939                   special diet
# 22086                      specialty
# 30864               meat & cold cuts
# 3895                          fruits
# 20267                     vegetables
# 55495                   coffee & tea
# 38972                      breakfast
# 4783                meat & cold cuts
# 42204                          meals
# 10541      frozen meals & appetizers
#
# [1000 rows x 8 columns]
